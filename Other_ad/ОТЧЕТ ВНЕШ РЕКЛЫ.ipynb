# %%
import pandas as pd
import datetime as dt
import numpy as np
import datetime as dt
import scipy.stats as stats
from io import BytesIO
import requests
pd.options.display.max_columns = None
from tkinter import *
from tkinter.filedialog import askopenfilename

# %% [markdown]
# # Подготовка отчета к замене id

# %%
#загрузка отчета для базы данных
file = askopenfilename()
report = pd.read_excel(file)
# report = pd.read_excel("/Users/drdim/Downloads/DFP_29.09.2020.xlsx")
report.head(100)
# Out:
#          date                                    acid_name  shows  clicks  \
# 0  2021-11-01  349 // Media Instinct // ZIC // 15.09-30.11      4       0
# 1  2021-11-02  349 // Media Instinct // ZIC // 15.09-30.11      5       1
# 2  2021-11-03  349 // Media Instinct // ZIC // 15.09-30.11  45002    2977
# 3  2021-11-04  349 // Media Instinct // ZIC // 15.09-30.11  45009    2772
# 4  2021-11-05  349 // Media Instinct // ZIC // 15.09-30.11  45009    2797
# ..        ...                                          ...    ...     ...
# 95 2021-11-13           Traffic // Nokian // Vianor // CPM    194       0
# 96 2021-11-13           Traffic // Nokian // Vianor // CPM   2267      14
# 97 2021-11-13           Traffic // Nokian // Vianor // CPM      7       0
# 98 2021-11-14           Traffic // Nokian // Vianor // CPM     31       2
# 99 2021-11-14           Traffic // Nokian // Vianor // CPM   5340      42
#
#           ctr  shows_price        cpc     cpm
# ...

# %%
report.drop(columns=['cpc'], inplace=True)

# %%
# report['Баннер'] = 0
# report['Доход'] = (report['Показы']/1000) * report['cpm']

# %%
# file = askopenfilename()
# old_all_report = pd.read_excel(file)
old_all_report = pd.read_excel("G:/Py3.7/Dev_old/Отчёт Внеш реклы BI для dropbox6.xlsx")

# %%
# report['РК'] = 'Arena || Роллтон'

# %%
# report = report[['Дата',
#  'Позиция',
#  'Размер креатива (показано)',
#  'Показы – сервер объявлений',
#  'Клики – сервер объявлений',
#  'Средняя эффективная цена за тысячу показов – сервер объявлений (₽)',
#  'CTR – сервер объявлений',
#  'Доход – сервер объявлений (цена за тысячу показов и цена за клик) (₽)']]

# %% [markdown]
# # База

# %%
# report.columns = ['Дата','Позиция','Баннер','Общие запросы','Общие показы','Доход']

# %%
# report['Всего кликов']=0
# report['Общий CTR']=0
report['Баннер'] = 0
# report['CPM']=0

# %%
report.columns = ['Дата','Позиция','Общие показы', 'Всего кликов', 'Общий CTR', 'Доход','CPM','Баннер']

# %% [markdown]
# # System

# %%
# report['Баннер'] = 0
# report.columns = ['Система', 'Позиция', 'Дата', 'Всего кликов', 'Общие показы', 'Доход', 'CPM', 'Баннер']
# report['Общий CTR'] = report['Всего кликов']/report['Общие показы']*100

# %%
# report.drop(report.tail(1).index,inplace=True)
# report['Дата'] = report['Дата'].dt.date
report
# Out:
#           Дата                                      Позиция  Общие показы  \
# 0   2021-11-01  349 // Media Instinct // ZIC // 15.09-30.11             4
# 1   2021-11-02  349 // Media Instinct // ZIC // 15.09-30.11             5
# 2   2021-11-03  349 // Media Instinct // ZIC // 15.09-30.11         45002
# 3   2021-11-04  349 // Media Instinct // ZIC // 15.09-30.11         45009
# 4   2021-11-05  349 // Media Instinct // ZIC // 15.09-30.11         45009
# ..         ...                                          ...           ...
# 133 2021-11-06              Сlickservice // Autoduty // CPC          5005
# 134 2021-11-07              Сlickservice // Autoduty // CPC          2501
# 135 2021-11-07              Сlickservice // Autoduty // CPC           833
# 136 2021-11-07              Сlickservice // Autoduty // CPC          3001
# 137 2021-11-07              Сlickservice // Autoduty // CPC          1001
#
#      Всего кликов  Общий CTR       Доход     CPM  Баннер
# ...

# %% [markdown]
# <h3>Замена кривых названий из отчета партнера на названия из справочника</h3>

# %%
report['Баннер'] = report['Баннер'].replace('1x1','Full Screen')

# %%
report['Позиция'] = report['Позиция'].str.replace('//','||', regex=False)
report['Позиция'] = report['Позиция'].str.replace('/','||', regex=False)
report['Позиция'] = report['Позиция'].replace("Futurist || CPC",'RBI Futurist CPC', regex=False)
report['Позиция'] = report['Позиция'].replace('Nokia 53 || Август || CPM','Nokia 53 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Владивосток || Native || Креатив 1|| CPM','S7_Summer Campaign || Владивосток || Native || Креатив 1 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Владивосток || Креатив 1|| CPM','S7_Summer Campaign || Владивосток || Креатив 1 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Владивосток || Креатив 2 || CPM','S7_Summer Campaign || Владивосток || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Иркутск || Native || Креатив 3 || CPM','S7_Summer Campaign || Иркутск || Native || Креатив 3 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Иркутск || Креатив 3 || CPM','S7_Summer Campaign || Иркутск || Креатив 3 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Москва || Native || Креатив 1|| CPM','S7_Summer Campaign || Москва || Native || Креатив 1 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Москва || Native || Креатив 2|| CPM','S7_Summer Campaign || Москва || Native || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Москва || Native || Креатив 3|| CPM','S7_Summer Campaign || Москва || Native || Креатив 3 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Москва || Креатив 1|| CPM','S7_Summer Campaign || Москва || Креатив 1 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Москва || Креатив 2 || CPM','S7_Summer Campaign || Москва || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Новосибирск || Native || Креатив 3 || CPM','S7_Summer Campaign || Новосибирск || Native || Креатив 3 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Новосибирск || Креатив 1|| CPM','S7_Summer Campaign || Новосибирск || Креатив 1 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Новосибирск || Креатив 2|| CPM','S7_Summer Campaign || Новосибирск || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Новосибирск || Креатив 3|| CPM','S7_Summer Campaign || Новосибирск || Креатив 3 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Иркутск || Креатив 1|| CPM','S7_Summer Campaign || Иркутск || Креатив 1 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Иркутск || Креатив 2 || CPM','S7_Summer Campaign || Иркутск || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август ||Иркутск || Native || Креатив 1|| CPM','S7_Summer Campaign || Иркутск || Native || Креатив 1 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Владивосток || Август || Native || Креатив 3 || CPM','S7_Summer Campaign || Владивосток || Native || Креатив 3 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Владивосток || Август || Native || Креатив 2 || CPM','S7_Summer Campaign || Владивосток || Native || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || РФ || Native || Креатив 1|| CPM','S7_Summer Campaign || РФ || Native || Креатив 1 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || РФ || Native || Креатив 2|| CPM','S7_Summer Campaign || РФ || Native || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || РФ || Native || Креатив 3|| CPM','S7_Summer Campaign || РФ || Native || Креатив 3 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('Ультра Сити || CPC','Ультра Сити', regex=False)
report['Позиция'] = report['Позиция'].replace('Эко сити || CPC','Эко сити', regex=False)
report['Позиция'] = report['Позиция'].replace('Русские сезоны || CPC ','Русские сезоны || CPC', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Иркутск || Native || Креатив 2 || CPM','S7_Summer Campaign || Иркутск || Native || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Новосибирск || Native || Креатив 1 || CPM','S7_Summer Campaign || Новосибирск || Native || Креатив 1 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август ||Иркутск || Креатив 2 || CPM','S7_Summer Campaign || Иркутск || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август ||Новосибирск || Native || Креатив 2 || CPM','S7_Summer Campaign || Новосибирск || Native || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Владивосток || Авугст || Native || Креатив 2 || CPM','S7_Summer Campaign || Владивосток || Native || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Москва || Креатив 2|| CPM','S7_Summer Campaign || Москва || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Новосибирск || Native || Креатив 1|| CPM','S7_Summer Campaign || Новосибирск || Native || Креатив 1 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace(' S7_Summer Campaign || Москва || Креатив 1 || CPM','S7_Summer Campaign || Москва || Креатив 1 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || Новосибирск || Native || Креатив 3|| CPM','S7_Summer Campaign || Новосибирск || Native || Креатив 3 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || РФ || Native || Креатив 2 || CPM','S7_Summer Campaign || РФ || Native || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || РФ || Native || Креатив 3 || CPM','S7_Summer Campaign || РФ || Native || Креатив 3 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || РФ || Креатив 1|| CPM','S7_Summer Campaign || РФ || Креатив 1 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август || РФ || Креатив 2 || CPM','S7_Summer Campaign || РФ || Креатив 2 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('S7_Summer Campaign || Август ||РФ || Креатив 3 || CPM','S7_Summer Campaign || РФ || Креатив 3 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('Сбербанк//Дальневосточный банк // ФРК3_ПК Осеннее промо || CPC','Сбербанк//Дальневосточный банк // ФРК3_ПК Осеннее промо || CPC', regex=False)
report['Позиция'] = report['Позиция'].replace('Midea || Сентябрь || CPC','Midea || CPC', regex=False)
report['Позиция'] = report['Позиция'].replace('Фетакса _Зарегистрировать чек || 7 -13 сент || CPM','Фетакса _Зарегистрировать чек', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito_Domoteka || Крео Стул || CPM','Avito_Domoteka || Крео стул || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('MF || T2 || RTK || Kiko Milano || CPC 181 300','Kiko Milano || CPC', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Auto Запчасти || Октябрь || CPM','Avito Auto Запчасти || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Auto Запчасти || Ноябрь || CPM','Avito Auto Запчасти || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('Дебетовая карта Сберкарта || Октябрь || CPM','Дебетовая карта Сберкарта || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('Дебетовая карта Сберкарта ||Ноябрь|| CPM','Дебетовая карта Сберкарта || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('Трамплин // BMW THE5 // 11.20 // CPM','Трамплин || BMW THE5 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace(' Рив_Гош','Рив_Гош', regex=False)
report['Позиция'] = report['Позиция'].replace('Pampadu // Конкуренты','Pampadu || Конкуренты', regex=False)
report['Позиция'] = report['Позиция'].replace('Pampadu // Страхование','Pampadu || Страхование', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Auto // 11.20 // Bayers','Avito Auto || Bayers', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Auto //Buyers','Avito Auto || Bayers', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Auto //  Sellers РФ','Avito Auto || РФ || Sellers', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Auto //Sellers регионы','Avito Auto || регионы || Sellers', regex=False)
report['Позиция'] = report['Позиция'].replace('Pampadu // 11.20 // Конкуренты','Pampadu || Конкуренты', regex=False)
report['Позиция'] = report['Позиция'].replace('Pampadu // 11.20 // Страхование','Pampadu || Страхование', regex=False)
report['Позиция'] = report['Позиция'].replace('Pampadu // 11.20// Конкуренты','Pampadu || Конкуренты', regex=False)
report['Позиция'] = report['Позиция'].replace('Pampadu // 11.20// Страхование','Pampadu || Страхование', regex=False)
report['Позиция'] = report['Позиция'].replace('MGcom // Рив_Гош // День рождения // магазины','MGcom || Рив_Гош || День рождения || Магазины', regex=False)
report['Позиция'] = report['Позиция'].replace('MGcom // Рив_Гош // День рождения // Не посещали магазин','MGcom || Рив_Гош || День рождения || Не посещали магазин', regex=False)
report['Позиция'] = report['Позиция'].replace('MGcom // Рив_Гош // Магазины','MGcom || Рив_Гош || Магазины', regex=False)
report['Позиция'] = report['Позиция'].replace('MGcom // Рив_Гош  // Магазины','MGcom || Рив_Гош || Магазины', regex=False)
report['Позиция'] = report['Позиция'].replace('MGcom // Рив_Гош // Не посещали магазин','MGcom || Рив_Гош || Не посещали магазин', regex=False)
report['Позиция'] = report['Позиция'].replace('MGcom // Рив_Гош  // Не посещали магазин','MGcom || Рив_Гош || Не посещали магазин', regex=False)
report['Позиция'] = report['Позиция'].replace('Ашан Чёрная Пятница // Sale','Ашан Чёрная Пятница || Sale', regex=False)
report['Позиция'] = report['Позиция'].replace('Ашан Чёрная Пятница // Shopping','Ашан Чёрная Пятница || Shopping', regex=False)
report['Позиция'] = report['Позиция'].replace('Ашан Чёрная Пятница // KeyWords','Ашан Чёрная Пятница || KeyWords', regex=False)
report['Позиция'] = report['Позиция'].replace('Kardiomagnil // Farma // Multi // CPM // Cr4 // Усиление','Kardiomagnil // Farma // Multi // CPM // Cr4', regex=False)
report['Позиция'] = report['Позиция'].replace('MGcom // Рив_Гош// Магазины','MGcom || Рив_Гош || Магазины', regex=False)
report['Позиция'] = report['Позиция'].replace('MGcom // Рив_Гош// Не посещали магазин','MGcom || Рив_Гош || Не посещали магазин', regex=False)
report['Позиция'] = report['Позиция'].replace('Pampadu // 11.20  // Конкуренты','Pampadu || Конкуренты', regex=False)
report['Позиция'] = report['Позиция'].replace('Pampadu // 11.20  // Страхование','Pampadu || Страхование', regex=False)
report['Позиция'] = report['Позиция'].replace('MGcom // Рив_Гош // Черная пятница // Магазины','MGcom || Рив_Гош || Черная пятница || Магазины', regex=False)
report['Позиция'] = report['Позиция'].replace('MGcom // Рив_Гош // Черная пятница // Не посещали магазин','MGcom || Рив_Гош || Черная пятница || Не посещали магазин', regex=False)
report['Позиция'] = report['Позиция'].replace('MGcom // Рив_Гош  // Черная пятница // Магазины','MGcom || Рив_Гош || Черная пятница || Магазины', regex=False)
report['Позиция'] = report['Позиция'].replace('MGcom // Рив_Гош  // Черная пятница // Не посещали магазин','MGcom || Рив_Гош || Черная пятница || Не посещали магазин', regex=False)
report['Позиция'] = report['Позиция'].replace('BMW Winter Travel // 12.20','BMW Winter Travel', regex=False)
report['Позиция'] = report['Позиция'].replace('Авито бизнес // Авто // 12.20','Авито бизнес || Авто', regex=False)
report['Позиция'] = report['Позиция'].replace('Авито бизнес // Бобер // 12.20','Авито бизнес || Бобер', regex=False)
report['Позиция'] = report['Позиция'].replace('Авито бизнес // Недвижимость // 12.20','Авито бизнес || Недвижимость', regex=False)
report['Позиция'] = report['Позиция'].replace('Авито бизнес // Фермер // 12.20','Авито бизнес || Фермер', regex=False)
report['Позиция'] = report['Позиция'].replace('Авито бизнес // Школа языков // 12.20','Авито бизнес || Школа языков', regex=False)
report['Позиция'] = report['Позиция'].replace('Авито самозанятые // Авто // 12.20','Авито самозанятые || Авто', regex=False)
report['Позиция'] = report['Позиция'].replace('Авито самозанятые // Бобер // 12.20','Авито самозанятые || Бобер', regex=False)
report['Позиция'] = report['Позиция'].replace('Авито самозанятые // Недвижимость // 12.20','Авито самозанятые || Недвижимость', regex=False)
report['Позиция'] = report['Позиция'].replace('Авито самозанятые // Фермер // 12.20','Авито самозанятые || Фермер', regex=False)
report['Позиция'] = report['Позиция'].replace('Авито самозанятые // Школа языков // 12.20','Авито самозанятые || Школа языков', regex=False)
report['Позиция'] = report['Позиция'].replace('Сбербанк сервис поиска работы // 12.20','Сбербанк || сервис поиска работы', regex=False)
report['Позиция'] = report['Позиция'].replace('Сбербанк ФРК4 // Auto_Mom','Сбербанк ФРК4 || Auto_Mom', regex=False)
report['Позиция'] = report['Позиция'].replace('Сбербанк ФРК4 // auto_phone','Сбербанк ФРК4 || Auto_phone', regex=False)
report['Позиция'] = report['Позиция'].replace('Сбербанк ФРК4 // Mom','Сбербанк ФРК4 || Mom', regex=False)
report['Позиция'] = report['Позиция'].replace('Ашан новый год // Подарки // 12.20','Ашан новый год || Подарки', regex=False)
report['Позиция'] = report['Позиция'].replace('Ашан новый год // Супермаркеты // 12.20','Ашан новый год || Супермаркеты', regex=False)
report['Позиция'] = report['Позиция'].replace('Ашан новый год // Шоппинг // 12.20','Ашан новый год || Шоппинг', regex=False)
report['Позиция'] = report['Позиция'].replace('ВГТРК // 24.12 - 31.12 // CPM','ВГТРК || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('Ашан новый год // Ключевые слова // 12.20','Ашан новый год || Ключевые слова', regex=False)
report['Позиция'] = report['Позиция'].replace('MF/T2/ // GroupM // Nivea // CPM_1RK(TPP) // RTK','GroupM || Nivea || CPM_1RK(TPP) || RTK', regex=False)
report['Позиция'] = report['Позиция'].replace('MF/T2/ // GroupM // Nivea // CPM_2RK(FB) // RTK','GroupM || Nivea || CPM_2RK(FB) || RTK', regex=False)
report['Позиция'] = report['Позиция'].replace('MF/T2/ // GroupM // Nivea // CPM_3RK(SEG) // RTK','GroupM || Nivea || CPM_3RK(SEG) || RTK', regex=False)
report['Позиция'] = report['Позиция'].replace('Multi // Abi // 12.20','Multi || Abi', regex=False)
report['Позиция'] = report['Позиция'].replace('Fullscreen // Abi // 12.20','Fullscreen || Abi', regex=False)
report['Позиция'] = report['Позиция'].replace('MF || RTK || RBI || Январь 2020 || Futurist || CPC 22 500','RBI || Futurist || CPC', regex=False)
report['Позиция'] = report['Позиция'].replace('MF || RTK || RBI || Январь 2021 || Ультра Сити || CPC || 22 500 крео2','RBI || Ультра Сити || CPC || крео2', regex=False)
report['Позиция'] = report['Позиция'].replace('MF || RTK || RBI || Январь 2021 || Эко сити || CPC 22 500','RBI || Эко сити || CPC', regex=False)
report['Позиция'] = report['Позиция'].replace('MF || RTK || RBI || Январь 2021 || Ультра Сити || CPC || 22 500 крео1','RBI || Ультра Сити || CPC || крео1', regex=False)
report['Позиция'] = report['Позиция'].replace('PHD // ŠKODA / Winter Service 01.21','PHD || SKODA || Winter Service', regex=False)
report['Позиция'] = report['Позиция'].replace('Futurist || CPC ','RBI || Futurist || CPC', regex=False)
report['Позиция'] = report['Позиция'].replace('Ультра Сити || CPC ||  крео2','RBI || Ультра Сити || CPC || крео2', regex=False)
report['Позиция'] = report['Позиция'].replace('Эко сити // Март 2021 // CPC','RBI || Эко сити || CPC', regex=False)
report['Позиция'] = report['Позиция'].replace('Ультра Сити || CPC ||  крео1','RBI || Ультра Сити || CPC || крео1', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Job // Москва // Крео1','Avito Job || Москва || крео1', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Job // Москва // Крео2','Avito Job || Москва || крео2', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Job // Москва // Крео3','Avito Job || Москва || крео3', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Job // Москва // Крео4','Avito Job || Москва || крео4', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Job // СПБ // Крео1','Avito Job || СПБ || крео1', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Job // СПБ // Крео2','Avito Job || СПБ || крео2', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Job // СПБ // Крео3','Avito Job || СПБ || крео3', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito Job // СПБ // Крео4','Avito Job || СПБ || крео4', regex=False)
report['Позиция'] = report['Позиция'].replace('Infiniti // QX80 // cpm 01.21','Infiniti || QX80 || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('Трамплин // SberPay // cpm','Трамплин || SberPay || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('Арена // Ролтон_Антипростуда // CPM','Арена || Ролтон Антипростуда || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('RTK // Арена // Ролтон_Антипростуда // CPM (копия 1)','Арена || Ролтон Антипростуда || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('RTK // Арена // Ролтон_Антипростуда // CPM','Арена || Ролтон Антипростуда || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace('Vital // Деринат // CPM // Women 25-55 // Время подумать о здоровье1','Vital || Деринат || CPM || Women 25-55 || Время подумать о здоровье 1', regex=False)
report['Позиция'] = report['Позиция'].replace('Vital // Деринат // CPM // Women 25-55 // Время подумать о здоровье2','Vital || Деринат || CPM || Women 25-55 || Время подумать о здоровье 2', regex=False)
report['Позиция'] = report['Позиция'].replace('Vital // Деринат // CPM // Women 25-55 // Ничего не забыли','Vital || Деринат || CPM || Women 25-55 || Ничего не забыли', regex=False)
report['Позиция'] = report['Позиция'].replace('Vital // Деринат // CPM // Women with child // Давай меняться','Vital || Деринат || CPM || Women with child || Давай меняться 1', regex=False)
report['Позиция'] = report['Позиция'].replace('Vital // Деринат // CPM // Women with child // Давай меняться2','Vital || Деринат || CPM || Women with child || Давай меняться 2', regex=False)
report['Позиция'] = report['Позиция'].replace('Vital // Деринат // CPM // Women with child // Ничего не забыли школьница','Vital || Деринат || CPM || Women with child || Ничего не забыли школьница', regex=False)
report['Позиция'] = report['Позиция'].replace('RTK // Alfadart_test','RTK || Alfadart_test', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito // ReSellers_Q1 // CPM // Екб_Новосиб // Set1','Avito || ReSellers_Q1 || CPM || Екб_Новосиб || Set1', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito // ReSellers_Q1 // CPM // Екб_Новосиб // Set2','Avito || ReSellers_Q1 || CPM || Екб_Новосиб || Set2', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito // ReSellers_Q1 // CPM // Мск_Спб // Set1','Avito || ReSellers_Q1 || CPM || Мск_Спб || Set1', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito // ReSellers_Q1 // CPM // Мск_Спб // Set2','Avito || ReSellers_Q1 || CPM || Мск_Спб || Set2', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito // ReSellers_Q1 // CPM // Тюмень // Set1','Avito || ReSellers_Q1 || CPM || Тюмень || Set1', regex=False)
report['Позиция'] = report['Позиция'].replace('Avito // ReSellers_Q1 // CPM // Тюмень // Set2','Avito || ReSellers_Q1 || CPM || Тюмень || Set2', regex=False)
report['Позиция'] = report['Позиция'].replace("Renault X52 Digital Mar'21 // CPC","Renault X52 Digital Mar 21 || CPC", regex=False)
report['Позиция'] = report['Позиция'].replace('Icon // Papik // CPM // 250+','Icon || Papik || CPM || 250+', regex=False)
report['Позиция'] = report['Позиция'].replace('Icon // СТС_Папик2 // CPM // 100-','Icon || СТС_Папик2 || CPM || 100-', regex=False)
report['Позиция'] = report['Позиция'].replace('Icon // СТС_Папик2 // CPM // 250+','Icon || СТС_Папик2 || CPM || 250+', regex=False)
report['Позиция'] = report['Позиция'].replace('Icon // СТС_Папик2 // CPM // 250-','Icon || СТС_Папик2 || CPM || 250-', regex=False)
report['Позиция'] = report['Позиция'].replace('Icon // СТС_Папик2 // CPM // MSK','Icon || СТС_Папик2 || CPM || MSK', regex=False)
report['Позиция'] = report['Позиция'].replace('MI // Zolla // CPC // 23.04-25.04', 'MI || Zolla || CPC || 23.04-25.04', regex=False)
report['Позиция'] = report['Позиция'].replace('RTK // QTM // ADMITAD // ARMANI // 439506 431572 439505', 'RTK || QTM || ADMITAD || ARMANI || 439506 431572 439505', regex=False)
report['Позиция'] = report['Позиция'].replace('RTK // QTM // ADMITAD // LEVEL KITCHEN // 431175 441069', 'RTK || QTM || ADMITAD || LEVEL KITCHEN || 431175 441069', regex=False)
report['Позиция'] = report['Позиция'].replace('MI // Zolla // CPC // 26.04-02.05', 'MI || Zolla || CPC || 26.04-02.05', regex=False)
report['Позиция'] = report['Позиция'].replace('Primaxetin ', 'Primaxetin', regex=False)
report['Позиция'] = report['Позиция'].replace('Реслип Видео ', 'Реслип Видео', regex=False)
report['Позиция'] = report['Позиция'].replace('MF||T2||RTK ||E-Promo || Rockwool ||CPM||05', 'MF || T2 || RTK ||E-Promo || Rockwool || CPM || 05', regex=False)
report['Позиция'] = report['Позиция'].replace('Genius || PML ||ФГ|| Гоголь парк || 06 || CPM', 'Genius || PML || Гоголь парк || CPM || 06', regex=False)
report['Позиция'] = report['Позиция'].replace('Genius||PML||Renesans', 'Genius || PML || Renesans', regex=False)
report['Позиция'] = report['Позиция'].replace('AdMile || Столото ', 'AdMile || Столото', regex=False)
report['Позиция'] = report['Позиция'].replace('Трамплин || Burger King || JCB ', 'Трамплин || Burger King || JCB', regex=False)
report['Позиция'] = report['Позиция'].replace(' Трамплин || Avito auto || Drom || CPM', 'Трамплин || Avito auto || Drom || CPM', regex=False)
report['Позиция'] = report['Позиция'].replace(' Трамплин || Avito Real estate || CPC', 'Трамплин || Avito Real estate || CPC', regex=False)
report['Позиция'] = report['Позиция'].replace('TRMPLN || Falconeri || 11 || CPM ||', 'TRMPLN || Falconeri || 11 || CPM', regex=False)
report['Позиция']
# Out:
# 0      349 || Media Instinct || ZIC || 15.09-30.11
# 1      349 || Media Instinct || ZIC || 15.09-30.11
# 2      349 || Media Instinct || ZIC || 15.09-30.11
# 3      349 || Media Instinct || ZIC || 15.09-30.11
# 4      349 || Media Instinct || ZIC || 15.09-30.11
#                           ...
# 133                Сlickservice || Autoduty || CPC
# 134                Сlickservice || Autoduty || CPC
# 135                Сlickservice || Autoduty || CPC
# 136                Сlickservice || Autoduty || CPC
# 137                Сlickservice || Autoduty || CPC
# Name: Позиция, Length: 138, dtype: object

# %%
#report.drop(['Показатель CTR для сервера объявлений'], axis='columns', inplace=True)

#report.columns.tolist()

#report = report[['Дата',
# 'Позиция',
# 'Количество показов для сервера объявлений',
# 'Количество кликов для сервера объявлений',
# 'Средняя эффективная цена за тысячу показов для сервера объявлений (₽)',                
# 'Размер показанного креатива',
# 'Доход для сервера объявлений (за тысячу показов и за клик) (₽)']]

# %% [markdown]
# # Merge наш отчет и справочник

# %%
#загрузка справочника
spravochnik = pd.read_csv("G:/Py3.7/Dbeaver/справочник bi эдбаннер1.csv", sep=";")
spravochnik.columns = ['Позиция', 'source_id']
spravochnik.loc[96] = ['Nokia || CPM', 96]
spravochnik.loc[97] = ['Сбербанк//Дальневосточный банк // ФРК3_ПК Осеннее промо || CPC', 97]
spravochnik.loc[98] = ['Ашан_День Рождения Ашан 2020 || Москва || CPM', 98]
spravochnik.loc[99] = ['Ашан_День Рождения Ашан 2020 || Сибирь || CPM', 99]
spravochnik.loc[100] = ['Ашан_День Рождения Ашан 2020 || СПБ || CPM', 100]
spravochnik.loc[101] = ['Ашан_День Рождения Ашан 2020 || Урал || CPM', 101]
spravochnik.loc[102] = ['Ашан_День Рождения Ашан 2020 || ЮФО || CPM', 102]
spravochnik.loc[103] = ['Ашан_День Рождения Ашан 2020 || Волжский || CPM', 103]
spravochnik.loc[104] = ['Midea || CPC', 104]
spravochnik.loc[105] = ['Сбербанк//Уральский банк || CPC', 105]
spravochnik.loc[106] = ['Kiko Milano || CPC', 106]
spravochnik.loc[107] = ['Альфа-Банк/ Альфа-карта реферальная про-грамма || 1 группа || CPC', 107]
spravochnik.loc[108] = ['Альфа-Банк/ Альфа-карта реферальная про-грамма || 2 группа || CPC', 108]
spravochnik.loc[109] = ['Avito_Domoteka || Крео дверь || CPM', 109]
spravochnik.loc[110] = ['Avito_Domoteka || Крео кресло || CPM', 110]
spravochnik.loc[111] = ['Avito_Domoteka || Крео стул || CPM', 111]
spravochnik.loc[112] = ['ВТБ КН', 112]
spravochnik.loc[113] = ['My Guru', 113]
spravochnik.loc[114] = ['Smart Speaker', 114]
spravochnik.loc[115] = ['Cloud Game', 115]
spravochnik.loc[116] = ['Licey', 116]
spravochnik.loc[117] = ['Alcon Tower || 1 рк сегмент посетители сайтов недвижки || CPC', 117]
spravochnik.loc[118] = ['Alcon Tower || 2 рк сегмент направ. звонков недвижка || CPC', 118]
spravochnik.loc[120] = ['Glo Hyper || ГЕО 14 городов || CPM', 120]
spravochnik.loc[121] = ['Glo Hyper || ГЕО MSK || CPM', 121]
spravochnik.loc[122] = ['Glo Hyper || ГЕО 141 городов || CPM', 122]
spravochnik.loc[127] = ['shoppinglive || CPM', 127]
spravochnik.loc[128] = ['Hugo Boss || CPM', 128]
spravochnik.loc[129] = ['Bonduelle || CPM', 129]
spravochnik.loc[130] = ['Avito Auto Запчасти || CPM', 130]
spravochnik.loc[131] = ['Stada/Кардиомагнил || Фарма || CPM', 131]
spravochnik.loc[132] = ['Дебетовая карта Сберкарта || CPM', 132]
spravochnik.loc[133] = ['Glenmark_Keto plus || CPM', 133]
spravochnik.loc[134] = ['Stada/Кардиомагнил || Медицинские услуги || CPM', 134]
spravochnik.loc[139] = ['Stada/Кардиомагнил || Красота и Здоровье || CPM', 139]
spravochnik.loc[140] = ['Рив_Гош', 140]
spravochnik.loc[141] = ['Kardiomagnil // Multi // CPM', 141]
spravochnik.loc[142] = ['Pampadu', 142]
spravochnik.loc[143] = ['Kardiomagnil // Farma // Multi // CPM // Cr1', 143]
spravochnik.loc[144] = ['Kardiomagnil // Farma // Multi // CPM // Cr2', 144]
spravochnik.loc[145] = ['Kardiomagnil // Farma // Multi // CPM // Cr3', 145]
spravochnik.loc[146] = ['Kardiomagnil // Farma // Multi // CPM // Cr4', 146]
spravochnik.loc[147] = ['Трамплин || BMW THE5 || CPM', 147]
spravochnik.loc[156] = ['Pampadu || Конкуренты', 156]
spravochnik.loc[157] = ['Pampadu || Страхование', 157]
spravochnik.loc[158] = ['Avito Auto || Bayers', 158]
spravochnik.loc[159] = ['Ультра Сити || CPC || крео1', 159]
spravochnik.loc[160] = ['Ультра Сити || CPC || крео2', 160]
spravochnik.loc[161] = ['Avito Auto || РФ || Sellers', 161]
spravochnik.loc[162] = ['Avito Auto || регионы || Sellers', 162]
spravochnik.loc[163] = ['MGcom || Рив_Гош || День рождения || Магазины', 163]
spravochnik.loc[164] = ['MGcom || Рив_Гош || День рождения || Не посещали магазин', 164]
spravochnik.loc[165] = ['MGcom || Рив_Гош || Магазины', 165]
spravochnik.loc[166] = ['MGcom || Рив_Гош || Не посещали магазин', 166]
spravochnik.loc[167] = ['Ашан Чёрная Пятница || Sale', 167]
spravochnik.loc[168] = ['Ашан Чёрная Пятница || Shopping', 168]
spravochnik.loc[188] = ['Ашан Чёрная Пятница || KeyWords', 188]
spravochnik.loc[190] = ['MGcom || Рив_Гош || Черная пятница || Магазины', 190]
spravochnik.loc[191] = ['MGcom || Рив_Гош || Черная пятница || Не посещали магазин', 191]
spravochnik.loc[192] = ['BMW Winter Travel', 192]
spravochnik.loc[195] = ['Artstudio || CPC', 195]
spravochnik.loc[196] = ['Болконский || CPC', 196]
spravochnik.loc[197] = ['Авито бизнес || Авто', 197]
spravochnik.loc[198] = ['Авито бизнес || Бобер', 198]
spravochnik.loc[199] = ['Авито бизнес || Недвижимость', 199]
spravochnik.loc[200] = ['Авито бизнес || Фермер', 200]
spravochnik.loc[201] = ['Авито бизнес || Школа языков', 201]
spravochnik.loc[202] = ['Авито самозанятые || Авто', 202]
spravochnik.loc[203] = ['Авито самозанятые || Бобер', 203]
spravochnik.loc[204] = ['Авито самозанятые || Недвижимость', 204]
spravochnik.loc[205] = ['Авито самозанятые || Фермер', 205]
spravochnik.loc[206] = ['Авито самозанятые || Школа языков', 206]
spravochnik.loc[207] = ['Сбербанк || сервис поиска работы', 207]
spravochnik.loc[208] = ['Сбербанк ФРК4 || Auto_Mom', 208]
spravochnik.loc[209] = ['Сбербанк ФРК4 || Auto_phone', 209]
spravochnik.loc[210] = ['Сбербанк ФРК4 || Mom', 210]
spravochnik.loc[211] = ['Ашан новый год || Подарки', 211]
spravochnik.loc[212] = ['Ашан новый год || Супермаркеты', 212]
spravochnik.loc[213] = ['Ашан новый год || Шоппинг', 213]
spravochnik.loc[214] = ['ВГТРК || CPM', 214]
spravochnik.loc[215] = ['Ашан новый год || Ключевые слова', 215]
spravochnik.loc[216] = ['GroupM || Nivea || CPM_1RK(TPP) || RTK', 216]
spravochnik.loc[217] = ['GroupM || Nivea || CPM_2RK(FB) || RTK', 217]
spravochnik.loc[218] = ['GroupM || Nivea || CPM_3RK(SEG) || RTK', 218]
spravochnik.loc[219] = ['Multi || Abi', 219]
spravochnik.loc[220] = ['Fullscreen || Abi', 220]
spravochnik.loc[221] = ['RBI || Futurist || CPC', 221]
spravochnik.loc[222] = ['RBI || Ультра Сити || CPC || крео2', 222]
spravochnik.loc[223] = ['RBI || Эко сити || CPC', 223]
spravochnik.loc[224] = ['RBI || Ультра Сити || CPC || крео1', 224]
spravochnik.loc[225] = ['PHD || SKODA || Winter Service', 225]
spravochnik.loc[226] = ['Avito Job || Москва || крео1', 226]
spravochnik.loc[227] = ['Avito Job || Москва || крео2', 227]
spravochnik.loc[228] = ['Avito Job || Москва || крео3', 228]
spravochnik.loc[229] = ['Avito Job || Москва || крео4', 229]
spravochnik.loc[230] = ['Avito Job || СПБ || крео1', 230]
spravochnik.loc[231] = ['Avito Job || СПБ || крео2', 231]
spravochnik.loc[232] = ['Avito Job || СПБ || крео3', 232]
spravochnik.loc[233] = ['Avito Job || СПБ || крео4', 233]
spravochnik.loc[234] = ['Infiniti || QX80 || CPM', 234]
spravochnik.loc[235] = ['Трамплин || SberPay || CPM', 235]
spravochnik.loc[236] = ['Арена || Ролтон Антипростуда || CPM', 236]
spravochnik.loc[237] = ['Vital || Деринат || CPM || Women 25-55 || Время подумать о здоровье 1', 237]
spravochnik.loc[238] = ['Vital || Деринат || CPM || Women 25-55 || Время подумать о здоровье 2', 238]
spravochnik.loc[239] = ['Vital || Деринат || CPM || Women 25-55 || Ничего не забыли', 239]
spravochnik.loc[240] = ['Vital || Деринат || CPM || Women with child || Давай меняться 1', 240]
spravochnik.loc[241] = ['Vital || Деринат || CPM || Women with child || Давай меняться 2', 241]
spravochnik.loc[242] = ['Vital || Деринат || CPM || Women with child || Ничего не забыли школьница', 242]
spravochnik.loc[243] = ['Sape', 243]
spravochnik.loc[244] = ['RTK || Alfadart_test', 244]
spravochnik.loc[245] = ['Avito || ReSellers_Q1 || CPM || Екб_Новосиб || Set1', 245]
spravochnik.loc[246] = ['Avito || ReSellers_Q1 || CPM || Екб_Новосиб || Set2', 246]
spravochnik.loc[247] = ['Avito || ReSellers_Q1 || CPM || Мск_Спб || Set1', 247]
spravochnik.loc[248] = ['Avito || ReSellers_Q1 || CPM || Мск_Спб || Set2', 248]
spravochnik.loc[249] = ['Avito || ReSellers_Q1 || CPM || Тюмень || Set1', 249]
spravochnik.loc[250] = ['Avito || ReSellers_Q1 || CPM || Тюмень || Set2', 250]
spravochnik.loc[251] = ['Renault X52 Digital Mar 21 || CPC', 251]
spravochnik.loc[252] = ['Icon || Papik || CPM || 250+', 252]
spravochnik.loc[253] = ['Icon || СТС_Папик2 || CPM || 100-', 253]
spravochnik.loc[254] = ['Icon || СТС_Папик2 || CPM || 250-', 254]
spravochnik.loc[255] = ['Icon || СТС_Папик2 || CPM || 250+', 255]
spravochnik.loc[256] = ['Icon || СТС_Папик2 || CPM || MSK', 256]
spravochnik.loc[257] = ['Трамплин || Avito General || CPM || Dacha',257]
spravochnik.loc[258] = ['Трамплин || Avito General || CPM || Dress',258]
spravochnik.loc[259] = ['Трамплин || Avito General || CPM || Obustroystvo',259]
spravochnik.loc[260] = ['Трамплин || Avito General || CPM || Pohod',260]
spravochnik.loc[261] = ['Трамплин || Avito Job || CPM || EKB || Cr1',261]
spravochnik.loc[262] = ['Трамплин || Avito Job || CPM || EKB || Cr2',262]
spravochnik.loc[263] = ['Трамплин || Avito Job || CPM || EKB || Cr3',263]
spravochnik.loc[264] = ['Трамплин || Avito Job || CPM || EKB || Cr4',264]
spravochnik.loc[265] = ['Трамплин || Avito Job || CPM || NSK || Cr1',265]
spravochnik.loc[266] = ['Трамплин || Avito Job || CPM || NSK || Cr2',266]
spravochnik.loc[267] = ['Трамплин || Avito Job || CPM || NSK || Cr3',267]
spravochnik.loc[268] = ['Трамплин || Avito Job || CPM || NSK || Cr4',268]
spravochnik.loc[269] = ['Трамплин || Heinz_Lenta promo || CPM',269]
spravochnik.loc[270] = ['RTK || Spar || Interests || MSK || Man 22-40',270]
spravochnik.loc[271] = ['RTK || Spar || Interests || MSK || Man 41-65',271]
spravochnik.loc[272] = ['RTK || Spar || Interests || MSK || Woman 22-40',272]
spravochnik.loc[273] = ['RTK || Spar || Interests || MSK || Woman 41-65',273]
spravochnik.loc[274] = ['RTK || Spar || Interests || SPB || Man 22-40',274]
spravochnik.loc[275] = ['RTK || Spar || Interests || SPB || Man 41-65',275]
spravochnik.loc[276] = ['RTK || Spar || Interests || SPB || Woman 22-40',276]
spravochnik.loc[277] = ['RTK || Spar || Interests || SPB || Woman 41-65',277]
spravochnik.loc[278] = ['RTK || Spar || Supergeo || MSK || Man 22-40',278]
spravochnik.loc[279] = ['RTK || Spar || Supergeo || MSK || Man 41-65',279]
spravochnik.loc[280] = ['RTK || Spar || Supergeo || MSK || Woman 22-40',280]
spravochnik.loc[281] = ['RTK || Spar || Supergeo || MSK || Woman 41-65',281]
spravochnik.loc[282] = ['RTK || Spar || Supergeo || SPB || Man 22-40',282]
spravochnik.loc[283] = ['RTK || Spar || Supergeo || SPB || Man 41-65',283]
spravochnik.loc[284] = ['RTK || Spar || Supergeo || SPB || Woman 22-40',284]
spravochnik.loc[285] = ['RTK || Spar || Supergeo || SPB || Woman 41-65',285]
spravochnik.loc[286] = ['MI || Zolla || CPC || 23.04-25.04', 286]
spravochnik.loc[287] = ['RTK || QTM || ADMITAD || ARMANI || 439506 431572 439505', 287]
spravochnik.loc[288] = ['RTK || QTM || ADMITAD || LEVEL KITCHEN || 431175 441069', 288]
spravochnik.loc[289] = ['MI || Zolla || CPC || 26.04-02.05', 289]
spravochnik.loc[290] = ['ICON || СТС_По колено || CPM || 250+', 290]
spravochnik.loc[303] = ['Реслип баннеры', 303]
spravochnik.loc[304] = ['Primaxetin', 304]
spravochnik.loc[305] = ['Реслип Видео', 305]
spravochnik.loc[307] = ['Adez || 03.21 || CPM || seg_RTK', 307]
spravochnik.loc[308] = ['Adez || Multiformat || seg_RTK', 308]
spravochnik.loc[309] = ['G fit 4S || RTK || Шины для авто', 309]
spravochnik.loc[310] = ['G fit EQ || РТК || АЗС', 310]
spravochnik.loc[311] = ['Z fit || РТК || Фанаты авто', 311]
spravochnik.loc[312] = ['NIvea || MicellAIR || Eco || seg_RTK', 312]
spravochnik.loc[313] = ['NIvea || MicellAIR || Beauty || seg_RTK', 313]
spravochnik.loc[314] = ['NIvea || MicellAIR || Buyers || seg_RTK', 314]
spravochnik.loc[322] = ['OptiFibre', 322]
spravochnik.loc[323] = ['HGTV', 323]
spravochnik.loc[324] = ['Rockwool', 324]
spravochnik.loc[325] = ['Arena || Роллтон', 325]
spravochnik.loc[329] = ['AdMile || Столото', 329]
spravochnik.loc[330] = ['MF || T2 || RTK ||E-Promo || Rockwool || CPM || 05', 330]
spravochnik.loc[331] = ['Genius || PML || Гоголь парк || CPM || 06', 331]
spravochnik.loc[332] = ['Genius || CartoonNetwork || 05-06 || CPM', 332]
spravochnik.loc[333] = ['Genius || PML || Renesans', 333]
spravochnik.loc[334] = ['PPL || Berghauf || Elast Premium || 3', 334]
spravochnik.loc[335] = ['PPL || Berghauf || Гидроизоляция || 1', 335]
spravochnik.loc[336] = ['PPL || Berghauf || Грунтовки || 2', 336]
spravochnik.loc[337] = ['Traffic Isobar || Lorenz || 06-07 || CPM', 337]
spravochnik.loc[338] = ['Трамплин || Avito service || CPM', 338]
spravochnik.loc[339] = ['Трамплин || Burger King || JCB', 339]
spravochnik.loc[340] = ['Трамплин || BlaBlaCar', 340]
spravochnik.loc[341] = ['Трамплин || Avito Auto || CPC', 341]
spravochnik.loc[342] = ['Resolution || Bosch MDA || CPM', 342]
spravochnik.loc[343] = ['MGCom || Лента || Бокалы Vivo', 343]
spravochnik.loc[344] = ['Трамплин || Avito auto || Drom || CPM', 344]
spravochnik.loc[353] = ['349 || Media Instinct || ZIC || 15.09-30.11', 353]
spravochnik.loc[354] = ['RTK || Subbota || 09 || CPM ', 354]
spravochnik.loc[355] = ['GG || Discovery || 09 || olv', 355]
spravochnik.loc[356] = ['PML || Mainstreet || 09 || CPM ', 356]
spravochnik.loc[357] = ['PBD || VTB || CPM', 357]
spravochnik.loc[358] = ['Сlickservice || Autoduty || CPC', 358]
spravochnik.loc[359] = ['Трамплин || Avito Real estate || CPC', 359]

spravochnik.loc[361] = ['TRMPLN || Falconeri || 11 || CPM', 361]
spravochnik.loc[362] = ['360 || PBD || Subbota Q4 || 11.11', 362]
spravochnik.loc[363] = ['PML || MGCom || Detralex || CPM', 363]
spravochnik.loc[364] = ['Traffic || Nokian || Vianor || CPM', 364]
spravochnik
# Out:
#                                   Позиция  source_id
# 0                                MyTarget          1
# 1                               Авито JOB          2
# 2                                 Пиксель          3
# 3                                  Яндекс          4
# 4                                Налгезин          5
# ..                                    ...        ...
# 359  Трамплин || Avito Real estate || CPC        359
# 361      TRMPLN || Falconeri || 11 || CPM        361
# 362     360 || PBD || Subbota Q4 || 11.11        362
# 363       PML || MGCom || Detralex || CPM        363
# 364    Traffic || Nokian || Vianor || CPM        364
#
# [294 rows x 2 columns]

# %% [markdown]
# # Выгрузка новых кампаний для справочника

# %%
spravochnik = spravochnik.rename(columns={'Позиция':'campaign'})
def system(data):
    if data['Система'] == 'MyTarget':
        gk_name = 'QM/MT'
    elif data['Система'] == 'Yandex':
        gk_name = 'QM/Yandex'
    else:
        gk_name = 'QM/AdBanner'
    return gk_name    

report = report.rename(columns={'Позиция':'campaign'})
if 'Система' in report.columns:
    report['gk_name'] = report.apply(system, axis = 1)
else:
    report['gk_name'] = 'QM/AdBanner'
    
    
spravochnik_bd = spravochnik[spravochnik['source_id'] > 359]
# spravochnik_bd.columns(['campaign', 'sourse_id'])
spravochnik_bd.drop_duplicates('source_id', inplace=True)
spravochnik_bd = spravochnik_bd.rename(columns={'Позиция':'campaign'})
spravochnik_bd[['campaign', 'source_id']].to_csv('G:/Py3.7/Dev_output/spravochnik_bd.csv', index=False, sep=";")

spravochnik_bd_2 = report.merge(spravochnik_bd, how='left')
# data = {'id':[107], 'gk_name':['Другие рекламодатели']}
spravochnik_bd_gk = pd.DataFrame(spravochnik_bd_2[['source_id', 'gk_name']])
spravochnik_bd_gk = spravochnik_bd_gk.rename(columns={'source_id':'gk_id'})
spravochnik_bd_gk.drop_duplicates('gk_id', inplace=True)
spravochnik_bd_gk.to_csv('G:/Py3.7/Dev_output/spravochnik_bd_gk.csv', index=False, sep=";")
# Out:
# G:\Prog\Anaconda\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
spravochnik_bd_gk
# Out:
#      gk_id      gk_name
# 0      NaN  QM/AdBanner
# 15   362.0  QM/AdBanner
# 20   363.0  QM/AdBanner
# 54   364.0  QM/AdBanner
# 108  361.0  QM/AdBanner

# %% [markdown]
# # Косячные строки

# %%
pd.options.display.max_colwidth = 100
watch_error = report.merge(spravochnik, how='left')
bool_series = pd.isnull(watch_error["source_id"])

watch_error[bool_series]['campaign'].unique()
# Out:
# array([], dtype=object)

# %% [markdown]
# # Merge

# %%
total = report.merge(spravochnik)
total.drop(['campaign'], axis='columns', inplace=True)
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 0 to 137
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Дата          138 non-null    datetime64[ns]
#  1   Общие показы  138 non-null    int64
#  2   Всего кликов  138 non-null    int64
#  3   Общий CTR     138 non-null    float64
#  4   Доход         138 non-null    float64
#  5   CPM           138 non-null    float64
#  6   Баннер        138 non-null    int64
#  7   gk_name       138 non-null    object
#  8   source_id     138 non-null    int64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(1)
# memory usage: 10.8+ KB

# %%
total_dly_concat = total.copy()

# %%
total.drop(['Общий CTR'], axis='columns', inplace=True)

# %%
total.columns.tolist()
# Out:
# ['Дата',
#  'Общие показы',
#  'Всего кликов',
#  'Доход',
#  'CPM',
#  'Баннер',
#  'gk_name',
#  'source_id']

# %%
total = total.rename(columns={'source_id':'id'})

# %%
total = total[['Дата',
                 'id',
                 'Общие показы',
                 'Всего кликов',
                 'CPM',
                 'Баннер',
                 'Доход']]

# %%
total['adb_segment']=0
total['adb_coverage']=0

# %%
total.columns = ['adb_extadv_date', 'adb_extadv_copmany', 'adb_extadv_view', 'adb_extadv_click', 'adb_extadv_cpm',
                'adb_extadv_banner', 'adb_extadv_revenue', 'adb_segment', 'adb_coverage']

# %%
total
# Out:
#     adb_extadv_date  adb_extadv_copmany  adb_extadv_view  adb_extadv_click  \
# 0        2021-11-01                 353                4                 0
# 1        2021-11-02                 353                5                 1
# 2        2021-11-03                 353            45002              2977
# 3        2021-11-04                 353            45009              2772
# 4        2021-11-05                 353            45009              2797
# ..              ...                 ...              ...               ...
# 133      2021-11-06                 358             5005                35
# 134      2021-11-07                 358             2501                14
# 135      2021-11-07                 358              833                10
# 136      2021-11-07                 358             3001                31
# 137      2021-11-07                 358             1001                 8
#
# ...

# %%
def out_red(text):
    print("\033[31m {}" .format(text))

# %%
print('Строк в отчете партнера:', len(report))
print('Строк в отчете на загрузку в BI:', len(total))
print()

if len(report) == len(total):
    print('Отлично, загружаем!')
    total.to_csv('G:/Py3.7/Dev_output/Отчёт Внеш реклы BI_1.csv', index=False, sep=";")
else:
    print('Есть косяки, не все кампании распознались :C ')
# Out:
# Строк в отчете партнера: 138
# Строк в отчете на загрузку в BI: 138
#
# Отлично, загружаем!

# %%
total['adb_extadv_date'] = total['adb_extadv_date'].dt.date

# %%
total.to_csv('G:/Py3.7/Dev_output/Отчёт Внеш реклы BI_{} {}.csv'.format(min(total['adb_extadv_date']),max(total['adb_extadv_date'])), index=False, sep=";")

# %%
total.head(100)
# Out:
#    adb_extadv_date  adb_extadv_copmany  adb_extadv_view  adb_extadv_click  \
# 0       2021-11-01                 353                4                 0
# 1       2021-11-02                 353                5                 1
# 2       2021-11-03                 353            45002              2977
# 3       2021-11-04                 353            45009              2772
# 4       2021-11-05                 353            45009              2797
# ..             ...                 ...              ...               ...
# 95      2021-11-13                 364              194                 0
# 96      2021-11-13                 364             2267                14
# 97      2021-11-13                 364                7                 0
# 98      2021-11-14                 364               31                 2
# 99      2021-11-14                 364             5340                42
#
#     adb_extadv_cpm  adb_extadv_banner  adb_extadv_revenue  adb_segment  \
# ...

# %% [markdown]
# # Склейка 2 отчетов для дроп бокса

# %%
old_all_report['Дата'] = old_all_report['Дата'].dt.date
old_all_report.tail(80)
# Out:
#              Дата  Позиция  Общие показы  Всего кликов        CPM  Общий CTR  \
# 10561  2021-03-29      307           193             0  49.971503   0.000000
# 10562  2021-03-29      307           245             0  48.826531   0.000000
# 10563  2021-04-26      309           357             0  45.840000   0.000000
# 10564  2021-04-27      309          5644             0  41.040000   0.000000
# 10565  2021-04-28      309          4835             1  41.000000   0.020683
# ...           ...      ...           ...           ...        ...        ...
# 10636  2021-05-27      244        811512             0  10.000000   0.000000
# 10637  2021-05-27      287          2509           141   0.000000   0.056198
# 10638  2021-05-27      287          1029             1   0.000000   0.000972
# 10639  2021-05-27      287            40             0   0.000000   0.000000
# 10640  2021-05-27      288            42             2   0.000000   0.047619
#
#             Баннер        Доход
# ...

# %%
total_dly_concat
# Out:
#           Дата  Общие показы  Всего кликов  Общий CTR       Доход     CPM  \
# 0   2021-11-01             4             0   0.000000     0.52500  131.25
# 1   2021-11-02             5             1  20.000000     0.65625  131.25
# 2   2021-11-03         45002          2977   6.615262  5906.51250  131.25
# 3   2021-11-04         45009          2772   6.158768  5907.43125  131.25
# 4   2021-11-05         45009          2797   6.214313  5907.43125  131.25
# ..         ...           ...           ...        ...         ...     ...
# 133 2021-11-06          5005            35   0.699301   970.97000  194.00
# 134 2021-11-07          2501            14   0.559776   485.19400  194.00
# 135 2021-11-07           833            10   1.200480   161.60200  194.00
# 136 2021-11-07          3001            31   1.032989   582.19400  194.00
# 137 2021-11-07          1001             8   0.799201   194.19400  194.00
#
#      Баннер      gk_name  source_id
# 0         0  QM/AdBanner        353
# ...

# %%
total_dly_concat = total_dly_concat[['Дата',
                 'source_id',
                 'Общие показы',
                 'Всего кликов',
                 'CPM',
                 'Общий CTR',
                 'Баннер',
                 'Доход']]
total_dly_concat.columns = ['Дата','Позиция','Общие показы','Всего кликов','CPM','Общий CTR','Баннер','Доход']

# %%
new_all_report = pd.concat([old_all_report, total_dly_concat])
new_all_report
# Out:
#                     Дата  Позиция  Общие показы  Всего кликов     CPM  \
# 0             2020-11-20      188             6             0   95.04
# 1             2020-11-20      188             1             0   95.04
# 2             2020-11-20      188             1             0   95.04
# 3             2020-11-21      188            13             0   95.04
# 4             2020-11-21      188             3             0   95.04
# ..                   ...      ...           ...           ...     ...
# 133  2021-11-06 00:00:00      358          5005            35  194.00
# 134  2021-11-07 00:00:00      358          2501            14  194.00
# 135  2021-11-07 00:00:00      358           833            10  194.00
# 136  2021-11-07 00:00:00      358          3001            31  194.00
# 137  2021-11-07 00:00:00      358          1001             8  194.00
#
#      Общий CTR       Баннер      Доход
# 0     0.000000  Full Screen    0.57024
# 1     0.000000      300x250    0.09504
# ...

# %%
if len(report) == len(total):
    print('Отлично, загружаем и в дроп бокс!')
    new_all_report.to_excel('G:/Py3.7/Dev_output/Отчёт Внеш реклы BI для dropbox6.xlsx', index=False)
else:
    print('Есть косяки, не все кампании распознались :C ')
# Out:
# Отлично, загружаем и в дроп бокс!

# %%
new_all_report
# Out:
#                     Дата  Позиция  Общие показы  Всего кликов     CPM  \
# 0             2020-11-20      188             6             0   95.04
# 1             2020-11-20      188             1             0   95.04
# 2             2020-11-20      188             1             0   95.04
# 3             2020-11-21      188            13             0   95.04
# 4             2020-11-21      188             3             0   95.04
# ..                   ...      ...           ...           ...     ...
# 133  2021-11-06 00:00:00      358          5005            35  194.00
# 134  2021-11-07 00:00:00      358          2501            14  194.00
# 135  2021-11-07 00:00:00      358           833            10  194.00
# 136  2021-11-07 00:00:00      358          3001            31  194.00
# 137  2021-11-07 00:00:00      358          1001             8  194.00
#
#      Общий CTR       Баннер      Доход
# 0     0.000000  Full Screen    0.57024
# 1     0.000000      300x250    0.09504
# ...
